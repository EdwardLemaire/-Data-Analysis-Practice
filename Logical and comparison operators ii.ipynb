# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # Logical and comparison operators ii
# © ExploreAI Academy

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# In this train we will learn:
# - How to use the IS NULL and IS NOT NULL statements
# - How to use the IS IN and IS NOT IN statements
# - Understand if there is any correlation between the GDP and availibility of drinking water and sanitation services in Sub-Saharan Africa

# %% [markdown]
# ## Connecting to our MySQL database
#
# Using our `Access_to_Basic_Services` table in our `united_nations` database we created in MySQL Workbench, we want to answer some questions about our dataset. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.

# %%
# Load and activate the SQL extension to allows us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql is installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command,
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:cillingsql@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %% [markdown]
# To make a query, we add the `%%sql` command to the start of a cell, create one open line and then the query like below and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('18.513673'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %% [markdown]
# ## Exercise

# %% [markdown]
# We will be working with the `united_nations.Access_to_Basic_Services` table, which contains information about different countries, their access to basic services, and their estimated GDP.
#
# In this exercise We would like to determine if the GDP of a country, specifically in Sub-Saharan Africa has any correlation to its access to basic services

# %% [markdown]
# ### Task 1
# Select data from the Sub-Saharan African region during the year 2020.

# %%
# %%sql
#
# SELECT
# *
# FROM
#     access_to_basic_services
# WHERE
#     time_period = 2020;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 165 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2020, Decimal('95.00'), Decimal('98.00'), Decimal('18.755666'), Decimal('171.08'), Decimal('2699700.00'), Decimal('4.89')),
#  ('Central and Southern Asia', 'Central Asia', 'Kyrgyzstan', 2020, Decimal('92.67'), Decimal('97.67'), None, None, None, None),
#  ('Central and Southern Asia', 'Central Asia', 'Tajikistan', 2020, Decimal('85.00'), Decimal('96.33'), Decimal('9.543207'), Decimal('8.13'), Decimal('138790.00'), None),
#  ('Central and Southern Asia', 'Central Asia', 'Turkmenistan', 2020, Decimal('100.00'), Decimal('99.33'), Decimal('6.250438'), None, Decimal('469930.00'), None),
#  ('Central and Southern Asia', 'Central Asia', 'Uzbekistan', 2020, Decimal('98.00'), Decimal('100.00'), Decimal('34.232050'), Decimal('59.89'), Decimal('440650.00'), Decimal('5.29')),
#  ('Central and Southern Asia', 'Southern Asia', 'Afghanistan', 2020, Decimal('80.33'), Decimal('54.00'), Decimal('38.972230'), Decimal('20.14'), Decimal('652230.00'), Decimal('11.71')),
#  ('Central and Southern Asia', 'Southern Asia', 'Bangladesh', 2020, Decimal('97.67'), Decimal('54.00'), Decimal('167.420951'), Decimal('373.90'), Decimal('130170.00'), None),
#  ('Central and Southern Asia', 'Southern Asia', 'Bhutan', 2020, Decimal('97.33'), Decimal('76.67'), Decimal('0.772506'), Decimal('2.33'), Decimal('38140.00'), Decimal('5.03')),
#  ('Central and Southern Asia', 'Southern Asia', 'India', 2020, Decimal('91.00'), Decimal('72.33'), Decimal('1396.387127'), Decimal('2667.69'), Decimal('2973190.00'), Decimal('7.86')),
#  ('Central and Southern Asia', 'Southern Asia', 'Iran (Islamic Republic of)', 2020, Decimal('96.67'), Decimal('88.33'), None, None, None, None),
#  ('Central and Southern Asia', 'Southern Asia', 'Maldives', 2020, Decimal('99.67'), Decimal('99.33'), Decimal('0.514438'), Decimal('3.75'), Decimal('300.00'), None),
#  ('Central and Southern Asia', 'Southern Asia', 'Nepal', 2020, Decimal('90.00'), Decimal('76.67'), Decimal('29.348627'), Decimal('33.43'), Decimal('143350.00'), None),
#  ('Central and Southern Asia', 'Southern Asia', 'Pakistan', 2020, Decimal('90.67'), Decimal('70.00'), Decimal('227.196741'), Decimal('300.43'), Decimal('770880.00'), None),
#  ('Central and Southern Asia', 'Southern Asia', 'Sri Lanka', 2020, Decimal('94.33'), Decimal('93.67'), Decimal('21.919000'), Decimal('85.35'), Decimal('61860.00'), Decimal('5.36')),
#  ('Eastern and South-Eastern Asia', 'Eastern Asia', 'China', 2020, Decimal('93.67'), Decimal('91.67'), Decimal('1411.100000'), Decimal('14687.67'), Decimal('9424702.90'), Decimal('5.61')),
#  ('Eastern and South-Eastern Asia', 'Eastern Asia', "Democratic People's Republic of Korea", 2020, Decimal('93.33'), Decimal('83.33'), None, None, None, None),
#  ('Eastern and South-Eastern Asia', 'Eastern Asia', 'Japan', 2020, Decimal('99.00'), Decimal('100.00'), Decimal('126.261000'), Decimal('5040.11'), Decimal('364500.00'), Decimal('2.81')),
#  ('Eastern and South-Eastern Asia', 'Eastern Asia', 'Mongolia', 2020, Decimal('81.00'), Decimal('65.00'), Decimal('3.294335'), Decimal('13.31'), Decimal('1557506.80'), Decimal('6.59')),
#  ('Eastern and South-Eastern Asia', 'Eastern Asia', 'Republic of Korea', 2020, Decimal('100.00'), Decimal('100.00'), None, None, None, None),
#  ('Eastern and South-Eastern Asia', 'South-Eastern Asia', 'Brunei Darussalam', 2020, Decimal('100.00'), None, Decimal('0.441725'), Decimal('12.01'), Decimal('5270.00'), Decimal('7.41')),
#  ('Eastern and South-Eastern Asia', 'South-Eastern Asia', 'Cambodia', 2020, Decimal('75.33'), Decimal('74.33'), Decimal('16.396860'), Decimal('25.87'), Decimal('176520.00'), None),
#  ('Eastern and South-Eastern Asia', 'South-Eastern Asia', 'Indonesia', 2020, Decimal('92.00'), Decimal('86.00'), Decimal('271.857970'), Decimal('1058.69'), Decimal('1877519.00'), Decimal('4.25')),
#  ('Eastern and South-Eastern Asia', 'South-Eastern Asia', "Lao People's Democratic Republic", 2020, Decimal('86.67'), Decimal('82.00'), None, None, None, None),
#  ('Eastern and South-Eastern Asia', 'South-Eastern Asia', 'Malaysia', 2020, Decimal('95.33'), Decimal('100.00'), Decimal('33.199993'), Decimal('337.34'), Decimal('328550.00'), Decimal('4.54')),
#  ('Eastern and South-Eastern Asia', 'South-Eastern Asia', 'Myanmar', 2020, Decimal('85.67'), Decimal('74.67'), Decimal('53.423198'), Decimal('78.93'), Decimal('652670.00'), Decimal('1.48')),
#  ('Eastern and South-Eastern Asia', 'South-Eastern Asia', 'Philippines', 2020, Decimal('94.00'), Decimal('82.00'), Decimal('112.190977'), Decimal('361.75'), Decimal('298170.00'), Decimal('2.52')),
#  ('Eastern and South-Eastern Asia', 'South-Eastern Asia', 'Singapore', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('5.685807'), Decimal('345.30'), Decimal('718.00'), Decimal('4.10')),
#  ('Eastern and South-Eastern Asia', 'South-Eastern Asia', 'Thailand', 2020, Decimal('100.00'), Decimal('98.67'), Decimal('71.475664'), Decimal('499.68'), Decimal('510890.00'), Decimal('1.10')),
#  ('Eastern and South-Eastern Asia', 'South-Eastern Asia', 'Timor-Leste', 2020, Decimal('87.00'), Decimal('60.00'), Decimal('1.299995'), Decimal('2.16'), Decimal('14870.00'), None),
#  ('Eastern and South-Eastern Asia', 'South-Eastern Asia', 'Viet Nam', 2020, Decimal('97.33'), Decimal('90.00'), None, None, None, None),
#  ('Europe and Northern America', 'Northern America', 'Bermuda', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('0.063893'), Decimal('6.89'), Decimal('54.00'), None),
#  ('Europe and Northern America', 'Northern America', 'Canada', 2020, Decimal('99.00'), Decimal('99.00'), Decimal('38.037204'), Decimal('1645.42'), Decimal('8965590.00'), Decimal('9.46')),
#  ('Europe and Northern America', 'Northern America', 'Greenland', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('0.056367'), Decimal('3.08'), Decimal('410450.00'), None),
#  ('Europe and Northern America', 'Northern America', 'Saint Pierre and Miquelon', 2020, Decimal('91.00'), Decimal('100.00'), None, None, None, None),
#  ('Europe and Northern America', 'Northern America', 'United States of America', 2020, Decimal('100.00'), Decimal('99.67'), None, None, None, None),
#  ('Latin America and the Caribbean', 'Caribbean', 'Barbados', 2020, Decimal('99.00'), Decimal('98.00'), Decimal('0.280693'), Decimal('4.67'), Decimal('430.00'), None),
#  ('Latin America and the Caribbean', 'Caribbean', 'British Virgin Islands', 2020, Decimal('100.00'), None, Decimal('0.030910'), None, Decimal('150.00'), None),
#  ('Latin America and the Caribbean', 'Caribbean', 'Cuba', 2020, Decimal('96.33'), Decimal('90.00'), Decimal('11.300698'), Decimal('107.35'), Decimal('103800.00'), None),
#  ('Latin America and the Caribbean', 'Caribbean', 'Dominican Republic', 2020, Decimal('95.00'), Decimal('84.33'), Decimal('10.999664'), Decimal('78.84'), Decimal('48310.00'), Decimal('6.13')),
#  ('Latin America and the Caribbean', 'Caribbean', 'Guadeloupe', 2020, Decimal('100.00'), Decimal('100.00'), None, None, None, None),
#  ('Latin America and the Caribbean', 'Caribbean', 'Haiti', 2020, Decimal('65.00'), Decimal('36.00'), Decimal('11.306801'), Decimal('14.51'), Decimal('27560.00'), None),
#  ('Latin America and the Caribbean', 'Caribbean', 'Jamaica', 2020, Decimal('90.33'), Decimal('87.00'), Decimal('2.820436'), Decimal('13.81'), Decimal('10830.00'), Decimal('6.50')),
#  ('Latin America and the Caribbean', 'Caribbean', 'Martinique', 2020, Decimal('100.00'), Decimal('100.00'), None, None, None, None),
#  ('Latin America and the Caribbean', 'Caribbean', 'Montserrat', 2020, Decimal('98.00'), Decimal('89.00'), None, None, None, None),
#  ('Latin America and the Caribbean', 'Caribbean', 'Puerto Rico', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('3.281538'), Decimal('103.02'), Decimal('8870.00'), None),
#  ('Latin America and the Caribbean', 'Caribbean', 'Saint Barthélemy', 2020, Decimal('100.00'), Decimal('100.00'), None, None, None, None),
#  ('Latin America and the Caribbean', 'Caribbean', 'Saint Lucia', 2020, Decimal('97.00'), Decimal('82.00'), None, None, None, None),
#  ('Latin America and the Caribbean', 'Caribbean', 'Saint Martin (French Part)', 2020, Decimal('100.00'), Decimal('100.00'), None, None, None, None),
#  ('Latin America and the Caribbean', 'Caribbean', 'Trinidad and Tobago', 2020, Decimal('99.00'), Decimal('94.00'), Decimal('1.518147'), Decimal('21.06'), Decimal('5130.00'), Decimal('4.21')),
#  ('Latin America and the Caribbean', 'Caribbean', 'United States Virgin Islands', 2020, Decimal('99.00'), Decimal('99.00'), None, None, None, None),
#  ('Latin America and the Caribbean', 'Central America', 'Belize', 2020, Decimal('98.33'), Decimal('88.67'), Decimal('0.394921'), Decimal('2.08'), Decimal('22810.00'), None),
#  ('Latin America and the Caribbean', 'Central America', 'Costa Rica', 2020, Decimal('100.00'), Decimal('97.67'), Decimal('5.123105'), Decimal('62.16'), Decimal('51060.00'), Decimal('16.43')),
#  ('Latin America and the Caribbean', 'Central America', 'El Salvador', 2020, Decimal('97.00'), Decimal('79.67'), Decimal('6.292731'), Decimal('24.56'), Decimal('20720.00'), Decimal('5.01')),
#  ('Latin America and the Caribbean', 'Central America', 'Guatemala', 2020, Decimal('94.00'), Decimal('67.67'), Decimal('16.858333'), Decimal('77.63'), Decimal('107160.00'), None),
#  ('Latin America and the Caribbean', 'Central America', 'Honduras', 2020, Decimal('95.33'), Decimal('83.33'), Decimal('10.121763'), Decimal('23.83'), Decimal('111890.00'), Decimal('10.68')),
#  ('Latin America and the Caribbean', 'Central America', 'Mexico', 2020, Decimal('99.33'), Decimal('90.67'), Decimal('125.998302'), Decimal('1090.52'), Decimal('1943950.00'), Decimal('4.44')),
#  ('Latin America and the Caribbean', 'Central America', 'Nicaragua', 2020, Decimal('79.33'), Decimal('71.67'), Decimal('6.755895'), Decimal('12.59'), Decimal('120340.00'), None),
#  ('Latin America and the Caribbean', 'Central America', 'Panama', 2020, Decimal('92.67'), Decimal('81.00'), Decimal('4.294396'), Decimal('53.98'), Decimal('74180.00'), Decimal('18.55')),
#  ('Latin America and the Caribbean', 'South America', 'Argentina', 2020, Decimal('100.00'), Decimal('99.00'), Decimal('45.376763'), Decimal('385.54'), Decimal('2736690.00'), Decimal('11.46')),
#  ('Latin America and the Caribbean', 'South America', 'Bolivia (Plurinational State of)', 2020, Decimal('90.67'), Decimal('61.67'), None, None, None, None),
#  ('Latin America and the Caribbean', 'South America', 'Brazil', 2020, Decimal('98.33'), Decimal('82.33'), Decimal('213.196304'), Decimal('1448.56'), Decimal('8358140.00'), Decimal('13.70')),
#  ('Latin America and the Caribbean', 'South America', 'Chile', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('19.300315'), Decimal('252.73'), Decimal('743532.00'), Decimal('10.94')),
#  ('Latin America and the Caribbean', 'South America', 'Colombia', 2020, Decimal('94.67'), Decimal('91.33'), Decimal('50.930662'), Decimal('270.30'), Decimal('1109500.00'), Decimal('15.98')),
#  ('Latin America and the Caribbean', 'South America', 'Ecuador', 2020, Decimal('94.00'), Decimal('91.33'), Decimal('17.588595'), Decimal('99.29'), Decimal('248360.00'), Decimal('6.11')),
#  ('Latin America and the Caribbean', 'South America', 'Falkland Islands (Malvinas)', 2020, Decimal('91.00'), Decimal('100.00'), None, None, None, None),
#  ('Latin America and the Caribbean', 'South America', 'French Guiana', 2020, Decimal('94.00'), Decimal('92.00'), None, None, None, None),
#  ('Latin America and the Caribbean', 'South America', 'Guyana', 2020, Decimal('96.67'), Decimal('87.33'), Decimal('0.797202'), Decimal('5.47'), Decimal('196850.00'), None),
#  ('Latin America and the Caribbean', 'South America', 'Paraguay', 2020, Decimal('99.67'), Decimal('92.00'), Decimal('6.618695'), Decimal('35.43'), Decimal('397300.00'), Decimal('7.55')),
#  ('Latin America and the Caribbean', 'South America', 'Peru', 2020, Decimal('90.33'), Decimal('74.33'), Decimal('33.304756'), Decimal('201.71'), Decimal('1280000.00'), Decimal('7.18')),
#  ('Latin America and the Caribbean', 'South America', 'Suriname', 2020, Decimal('98.00'), Decimal('88.67'), Decimal('0.607065'), Decimal('2.91'), Decimal('156000.00'), None),
#  ('Latin America and the Caribbean', 'South America', 'Uruguay', 2020, Decimal('98.00'), Decimal('98.33'), Decimal('3.429086'), Decimal('53.56'), Decimal('175020.00'), Decimal('10.33')),
#  ('Latin America and the Caribbean', 'South America', 'Venezuela (Bolivarian Republic of)', 2020, Decimal('94.00'), Decimal('96.00'), None, None, None, None),
#  ('Northern Africa and Western Asia', 'Northern Africa', 'Algeria', 2020, Decimal('93.33'), Decimal('84.33'), Decimal('43.451666'), Decimal('145.01'), Decimal('2381741.00'), None),
#  ('Northern Africa and Western Asia', 'Northern Africa', 'Egypt', 2020, Decimal('99.33'), Decimal('97.67'), None, None, None, None),
#  ('Northern Africa and Western Asia', 'Northern Africa', 'Libya', 2020, Decimal('100.00'), Decimal('92.00'), Decimal('6.653942'), Decimal('50.36'), Decimal('1759540.00'), None),
#  ('Northern Africa and Western Asia', 'Northern Africa', 'Morocco', 2020, Decimal('88.33'), Decimal('84.67'), Decimal('36.688772'), Decimal('121.35'), Decimal('446300.00'), None),
#  ('Northern Africa and Western Asia', 'Northern Africa', 'Sudan', 2020, Decimal('62.33'), Decimal('40.33'), Decimal('44.440486'), Decimal('27.03'), Decimal('1868000.00'), None),
#  ('Northern Africa and Western Asia', 'Northern Africa', 'Tunisia', 2020, Decimal('97.00'), Decimal('97.33'), Decimal('12.161723'), Decimal('42.54'), Decimal('155360.00'), None),
#  ('Northern Africa and Western Asia', 'Western Asia', 'Armenia', 2020, Decimal('100.00'), Decimal('92.33'), Decimal('2.805608'), Decimal('12.64'), Decimal('28470.00'), Decimal('12.18')),
#  ('Northern Africa and Western Asia', 'Western Asia', 'Azerbaijan', 2020, Decimal('95.67'), Decimal('96.00'), Decimal('10.093121'), Decimal('42.69'), Decimal('82646.00'), Decimal('7.16')),
#  ('Northern Africa and Western Asia', 'Western Asia', 'Bahrain', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('1.477469'), Decimal('34.72'), Decimal('785.00'), None),
#  ('Northern Africa and Western Asia', 'Western Asia', 'Cyprus', 2020, Decimal('100.00'), Decimal('99.33'), Decimal('1.237537'), Decimal('25.01'), Decimal('9240.00'), Decimal('7.76')),
#  ('Northern Africa and Western Asia', 'Western Asia', 'Georgia', 2020, Decimal('96.67'), Decimal('84.33'), Decimal('3.722716'), Decimal('15.84'), Decimal('69490.00'), Decimal('11.73')),
#  ('Northern Africa and Western Asia', 'Western Asia', 'Iraq', 2020, Decimal('97.67'), Decimal('100.00'), Decimal('42.556984'), Decimal('184.37'), Decimal('434128.00'), None),
#  ('Northern Africa and Western Asia', 'Western Asia', 'Israel', 2020, Decimal('100.00'), Decimal('99.67'), Decimal('9.215100'), Decimal('413.27'), Decimal('21640.00'), Decimal('4.17')),
#  ('Northern Africa and Western Asia', 'Western Asia', 'Jordan', 2020, Decimal('98.33'), Decimal('96.33'), Decimal('10.928721'), Decimal('44.18'), Decimal('88794.00'), Decimal('19.21')),
#  ('Northern Africa and Western Asia', 'Western Asia', 'Kuwait', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('4.360444'), Decimal('105.96'), Decimal('17820.00'), None),
#  ('Northern Africa and Western Asia', 'Western Asia', 'Lebanon', 2020, Decimal('93.00'), Decimal('99.00'), Decimal('5.662923'), Decimal('31.71'), Decimal('10230.00'), None),
#  ('Northern Africa and Western Asia', 'Western Asia', 'Oman', 2020, Decimal('87.67'), Decimal('99.00'), Decimal('4.543399'), Decimal('75.91'), Decimal('309500.00'), Decimal('2.94')),
#  ('Northern Africa and Western Asia', 'Western Asia', 'Qatar', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('2.760385'), Decimal('144.41'), Decimal('11490.00'), Decimal('0.14')),
#  ('Northern Africa and Western Asia', 'Western Asia', 'Saudi Arabia', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('35.997107'), Decimal('703.37'), Decimal('2149690.00'), Decimal('7.66')),
#  ('Northern Africa and Western Asia', 'Western Asia', 'State of Palestine', 2020, Decimal('98.33'), Decimal('98.67'), None, None, None, None),
#  ('Northern Africa and Western Asia', 'Western Asia', 'Syrian Arab Republic', 2020, Decimal('93.67'), Decimal('90.00'), Decimal('20.772595'), Decimal('11.08'), Decimal('183630.00'), None),
#  ('Northern Africa and Western Asia', 'Western Asia', 'Türkiye', 2020, Decimal('96.67'), Decimal('98.67'), None, None, None, None),
#  ('Northern Africa and Western Asia', 'Western Asia', 'United Arab Emirates', 2020, Decimal('100.00'), Decimal('99.00'), Decimal('9.287289'), Decimal('349.47'), Decimal('71020.00'), Decimal('4.29')),
#  ('Northern Africa and Western Asia', 'Western Asia', 'Yemen', 2020, Decimal('63.00'), Decimal('57.33'), None, None, None, None),
#  ('Oceania', 'Australia and New Zealand', 'Australia', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('25.655289'), Decimal('1326.90'), Decimal('7692020.00'), Decimal('6.46')),
#  ('Oceania', 'Australia and New Zealand', 'New Zealand', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('5.090200'), Decimal('211.73'), Decimal('263310.00'), Decimal('4.60')),
#  ('Oceania', 'Melanesia', 'Fiji', 2020, Decimal('93.67'), Decimal('99.00'), Decimal('0.920422'), Decimal('4.48'), Decimal('18270.00'), None),
#  ('Oceania', 'Melanesia', 'New Caledonia', 2020, Decimal('99.00'), Decimal('100.00'), Decimal('0.271130'), Decimal('9.44'), Decimal('18280.00'), Decimal('13.56')),
#  ('Oceania', 'Melanesia', 'Papua New Guinea', 2020, Decimal('56.67'), Decimal('27.67'), Decimal('9.749640'), Decimal('23.85'), Decimal('452860.00'), None),
#  ('Oceania', 'Melanesia', 'Solomon Islands', 2020, Decimal('72.33'), Decimal('44.67'), Decimal('0.691191'), Decimal('1.54'), Decimal('27990.00'), None),
#  ('Oceania', 'Melanesia', 'Vanuatu', 2020, Decimal('93.00'), Decimal('55.67'), Decimal('0.311685'), Decimal('0.90'), Decimal('12190.00'), Decimal('4.05')),
#  ('Oceania', 'Micronesia', 'Guam', 2020, Decimal('100.00'), None, Decimal('0.169231'), Decimal('5.89'), Decimal('540.00'), None),
#  ('Oceania', 'Micronesia', 'Kiribati', 2020, Decimal('77.00'), Decimal('45.33'), Decimal('0.126463'), Decimal('0.18'), Decimal('810.00'), Decimal('10.97')),
#  ('Oceania', 'Micronesia', 'Marshall Islands', 2020, Decimal('90.00'), Decimal('78.00'), Decimal('0.043413'), Decimal('0.24'), Decimal('180.00'), None),
#  ('Oceania', 'Micronesia', 'Nauru', 2020, Decimal('100.00'), None, Decimal('0.012315'), Decimal('0.11'), Decimal('20.00'), None),
#  ('Oceania', 'Micronesia', 'Northern Mariana Islands', 2020, Decimal('100.00'), Decimal('79.00'), Decimal('0.049587'), None, Decimal('460.00'), None),
#  ('Oceania', 'Micronesia', 'Palau', 2020, Decimal('100.00'), Decimal('99.67'), Decimal('0.017972'), Decimal('0.25'), Decimal('460.00'), Decimal('0.77')),
#  ('Oceania', 'Polynesia', 'American Samoa', 2020, Decimal('100.00'), Decimal('54.00'), Decimal('0.046189'), Decimal('0.72'), Decimal('200.00'), None),
#  ('Oceania', 'Polynesia', 'Cook Islands', 2020, Decimal('100.00'), Decimal('99.00'), None, None, None, None),
#  ('Oceania', 'Polynesia', 'French Polynesia', 2020, Decimal('100.00'), Decimal('97.00'), Decimal('0.301920'), Decimal('5.71'), Decimal('3471.00'), None),
#  ('Oceania', 'Polynesia', 'Niue', 2020, Decimal('97.00'), Decimal('96.00'), None, None, None, None),
#  ('Oceania', 'Polynesia', 'Samoa', 2020, Decimal('92.00'), Decimal('96.33'), Decimal('0.214929'), Decimal('0.87'), Decimal('2780.00'), None),
#  ('Oceania', 'Polynesia', 'Tokelau', 2020, Decimal('100.00'), Decimal('97.00'), None, None, None, None),
#  ('Oceania', 'Polynesia', 'Tonga', 2020, Decimal('99.00'), Decimal('93.33'), Decimal('0.105254'), Decimal('0.48'), Decimal('720.00'), None),
#  ('Oceania', 'Polynesia', 'Tuvalu', 2020, Decimal('100.00'), None, Decimal('0.011069'), Decimal('0.06'), Decimal('30.00'), None),
#  ('Oceania', 'Polynesia', 'Wallis and Futuna Islands', 2020, Decimal('99.00'), Decimal('93.00'), None, None, None, None),
#  ('Sub-Saharan Africa', 'Eastern Africa', 'Burundi', 2020, Decimal('70.33'), Decimal('44.33'), Decimal('12.220227'), Decimal('2.65'), Decimal('25680.00'), Decimal('1.03')),
#  ('Sub-Saharan Africa', 'Eastern Africa', 'Djibouti', 2020, Decimal('69.00'), Decimal('56.00'), Decimal('1.090156'), Decimal('3.18'), Decimal('23180.00'), None),
#  ('Sub-Saharan Africa', 'Eastern Africa', 'Ethiopia', 2020, Decimal('58.00'), Decimal('11.67'), Decimal('117.190911'), Decimal('107.66'), Decimal('1128571.26'), None),
#  ('Sub-Saharan Africa', 'Eastern Africa', 'Kenya', 2020, Decimal('67.00'), Decimal('33.67'), Decimal('51.985780'), Decimal('100.67'), Decimal('569140.00'), None),
#  ('Sub-Saharan Africa', 'Eastern Africa', 'Madagascar', 2020, Decimal('56.33'), Decimal('13.00'), Decimal('28.225177'), Decimal('13.05'), Decimal('581800.00'), None),
#  ('Sub-Saharan Africa', 'Eastern Africa', 'Malawi', 2020, Decimal('74.33'), Decimal('28.67'), Decimal('19.377061'), Decimal('12.18'), Decimal('94280.00'), Decimal('0.91')),
#  ('Sub-Saharan Africa', 'Eastern Africa', 'Mauritius', 2020, Decimal('100.00'), Decimal('96.00'), Decimal('1.265740'), Decimal('11.40'), Decimal('2030.00'), Decimal('8.63')),
#  ('Sub-Saharan Africa', 'Eastern Africa', 'Mayotte', 2020, Decimal('96.00'), Decimal('100.00'), None, None, None, None),
#  ('Sub-Saharan Africa', 'Eastern Africa', 'Mozambique', 2020, Decimal('66.67'), Decimal('40.33'), Decimal('31.178239'), Decimal('14.03'), Decimal('786380.00'), None),
#  ('Sub-Saharan Africa', 'Eastern Africa', 'Rwanda', 2020, Decimal('66.33'), Decimal('64.00'), Decimal('13.146362'), Decimal('10.18'), Decimal('24670.00'), Decimal('11.83')),
#  ('Sub-Saharan Africa', 'Eastern Africa', 'Réunion', 2020, Decimal('100.00'), Decimal('100.00'), None, None, None, None),
#  ('Sub-Saharan Africa', 'Eastern Africa', 'Somalia', 2020, Decimal('57.33'), Decimal('40.00'), Decimal('16.537016'), Decimal('6.88'), Decimal('627340.00'), None),
#  ('Sub-Saharan Africa', 'Eastern Africa', 'South Sudan', 2020, Decimal('48.33'), Decimal('22.33'), Decimal('10.606227'), None, Decimal('631930.00'), None),
#  ('Sub-Saharan Africa', 'Eastern Africa', 'Uganda', 2020, Decimal('61.00'), Decimal('21.67'), Decimal('44.404611'), Decimal('37.60'), Decimal('200520.00'), None),
#  ('Sub-Saharan Africa', 'Eastern Africa', 'United Republic of Tanzania', 2020, Decimal('65.00'), Decimal('34.00'), None, None, None, None),
#  ('Sub-Saharan Africa', 'Eastern Africa', 'Zambia', 2020, Decimal('66.67'), Decimal('32.67'), Decimal('18.927715'), Decimal('18.11'), Decimal('743390.00'), Decimal('6.03')),
#  ('Sub-Saharan Africa', 'Eastern Africa', 'Zimbabwe', 2020, Decimal('68.00'), Decimal('36.33'), Decimal('15.669666'), Decimal('21.51'), Decimal('386850.00'), None),
#  ('Sub-Saharan Africa', 'Middle Africa', 'Angola', 2020, Decimal('52.33'), Decimal('47.00'), Decimal('33.428486'), Decimal('53.62'), Decimal('1246700.00'), None),
#  ('Sub-Saharan Africa', 'Middle Africa', 'Cameroon', 2020, Decimal('64.00'), Decimal('43.00'), Decimal('26.491087'), Decimal('40.77'), Decimal('472710.00'), None),
#  ('Sub-Saharan Africa', 'Middle Africa', 'Central African Republic', 2020, Decimal('38.33'), Decimal('15.00'), Decimal('5.343020'), Decimal('2.33'), Decimal('622980.00'), None),
#  ('Sub-Saharan Africa', 'Middle Africa', 'Chad', 2020, Decimal('52.67'), Decimal('18.67'), Decimal('16.644701'), Decimal('10.72'), Decimal('1259200.00'), None),
#  ('Sub-Saharan Africa', 'Middle Africa', 'Congo', 2020, Decimal('69.00'), Decimal('17.67'), None, None, None, None),
#  ('Sub-Saharan Africa', 'Middle Africa', 'Democratic Republic of the Congo', 2020, Decimal('47.67'), Decimal('15.33'), None, None, None, None),
#  ('Sub-Saharan Africa', 'Middle Africa', 'Gabon', 2020, Decimal('73.33'), Decimal('47.00'), Decimal('2.292573'), Decimal('15.31'), Decimal('257670.00'), None),
#  ('Sub-Saharan Africa', 'Middle Africa', 'Sao Tome and Principe', 2020, Decimal('77.33'), Decimal('46.00'), Decimal('0.218641'), Decimal('0.47'), Decimal('960.00'), None),
#  ('Sub-Saharan Africa', 'Southern Africa', 'Botswana', 2020, Decimal('89.67'), Decimal('74.33'), Decimal('2.546402'), Decimal('14.93'), Decimal('566730.00'), Decimal('21.02')),
#  ('Sub-Saharan Africa', 'Southern Africa', 'Eswatini', 2020, Decimal('76.67'), Decimal('61.33'), Decimal('1.180655'), Decimal('3.98'), Decimal('17200.00'), None),
#  ('Sub-Saharan Africa', 'Southern Africa', 'Lesotho', 2020, Decimal('76.33'), Decimal('49.67'), Decimal('2.254100'), Decimal('2.23'), Decimal('30360.00'), None),
#  ('Sub-Saharan Africa', 'Southern Africa', 'Namibia', 2020, Decimal('83.67'), Decimal('35.00'), Decimal('2.489098'), Decimal('10.58'), Decimal('823290.00'), None),
#  ('Sub-Saharan Africa', 'Southern Africa', 'South Africa', 2020, Decimal('92.00'), Decimal('78.67'), Decimal('58.801927'), Decimal('337.62'), Decimal('1213090.00'), Decimal('24.34')),
#  ('Sub-Saharan Africa', 'Western Africa', 'Benin', 2020, Decimal('65.33'), Decimal('17.33'), Decimal('12.643123'), Decimal('15.65'), Decimal('112760.00'), None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Burkina Faso', 2020, Decimal('53.33'), Decimal('25.00'), Decimal('21.522626'), Decimal('17.93'), Decimal('273600.00'), None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Cabo Verde', 2020, Decimal('87.33'), Decimal('78.00'), Decimal('0.582640'), Decimal('1.70'), Decimal('4030.00'), None),
#  ('Sub-Saharan Africa', 'Western Africa', "Côte d'Ivoire", 2020, Decimal('70.67'), Decimal('34.67'), None, None, None, None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Gambia', 2020, Decimal('79.33'), Decimal('44.33'), None, None, None, None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Ghana', 2020, Decimal('84.67'), Decimal('23.00'), Decimal('32.180401'), Decimal('70.04'), Decimal('227533.00'), None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Guinea', 2020, Decimal('67.33'), Decimal('32.33'), Decimal('13.205153'), Decimal('14.18'), Decimal('245720.00'), None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Guinea-Bissau', 2020, Decimal('60.00'), Decimal('19.33'), Decimal('2.015828'), Decimal('1.43'), Decimal('28120.00'), None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Liberia', 2020, Decimal('75.00'), Decimal('17.67'), Decimal('5.087584'), Decimal('3.04'), Decimal('96320.00'), None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Mali', 2020, Decimal('83.67'), Decimal('46.00'), Decimal('21.224040'), Decimal('17.47'), Decimal('1220190.00'), Decimal('3.53')),
#  ('Sub-Saharan Africa', 'Western Africa', 'Mauritania', 2020, Decimal('70.33'), Decimal('48.00'), Decimal('4.498604'), Decimal('8.41'), Decimal('1030700.00'), None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Niger', 2020, Decimal('57.33'), Decimal('24.67'), Decimal('24.333639'), Decimal('13.74'), Decimal('1266700.00'), None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Nigeria', 2020, Decimal('77.33'), Decimal('42.67'), Decimal('208.327405'), Decimal('432.20'), Decimal('910770.00'), None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Saint Helena', 2020, Decimal('99.00'), Decimal('100.00'), None, None, None, None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Senegal', 2020, Decimal('85.00'), Decimal('57.00'), Decimal('16.436120'), Decimal('24.49'), Decimal('192530.00'), None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Sierra Leone', 2020, Decimal('65.00'), Decimal('17.33'), Decimal('8.233970'), Decimal('4.06'), Decimal('72180.00'), None),
#  ('Sub-Saharan Africa', 'Western Africa', 'Togo', 2020, Decimal('70.67'), Decimal('20.00'), Decimal('8.442580'), Decimal('7.57'), Decimal('54390.00'), None)]

# %% [markdown]
# ### Task 2
#
# Sometimes there are null values in our entries. Any country having Null values for their GDP should not be included in our query as they will not help us determine if there is any correlation between GDP and access to basic services. For this task determine if there are any NULL values in the GDP column

# %%
# %%sql
# # Add your code here
# SELECT
# 	Country_name,
# 	Time_period,
# 	Pct_managed_drinking_water_services,
# 	Pct_managed_sanitation_services,
# 	Est_gdp_in_billions,
#     region
# FROM
# 	united_nations.Access_to_Basic_Services
# WHERE
# 	region = 'Sub-Saharan Africa'
# AND
# 	Time_period = 2020
# AND
# 	Est_gdp_in_billions IS NULL;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 9 rows affected.
# [('Mayotte', 2020, Decimal('96.00'), Decimal('100.00'), None, 'Sub-Saharan Africa'),
#  ('Réunion', 2020, Decimal('100.00'), Decimal('100.00'), None, 'Sub-Saharan Africa'),
#  ('South Sudan', 2020, Decimal('48.33'), Decimal('22.33'), None, 'Sub-Saharan Africa'),
#  ('United Republic of Tanzania', 2020, Decimal('65.00'), Decimal('34.00'), None, 'Sub-Saharan Africa'),
#  ('Congo', 2020, Decimal('69.00'), Decimal('17.67'), None, 'Sub-Saharan Africa'),
#  ('Democratic Republic of the Congo', 2020, Decimal('47.67'), Decimal('15.33'), None, 'Sub-Saharan Africa'),
#  ("Côte d'Ivoire", 2020, Decimal('70.67'), Decimal('34.67'), None, 'Sub-Saharan Africa'),
#  ('Gambia', 2020, Decimal('79.33'), Decimal('44.33'), None, 'Sub-Saharan Africa'),
#  ('Saint Helena', 2020, Decimal('99.00'), Decimal('100.00'), None, 'Sub-Saharan Africa')]

# %% [markdown]
# ### Task 3
#
# If there are any Null values exclude them from your query.

# %%
# %%sql
# # Add your code here
# SELECT
# 	Country_name,
# 	Time_period,
# 	Pct_managed_drinking_water_services,
# 	Pct_managed_sanitation_services,
# 	Est_gdp_in_billions,
#     region
# FROM
# 	united_nations.Access_to_Basic_Services
# WHERE
# 	region = 'Sub-Saharan Africa'
# AND
# 	Time_period = 2020
# AND
# 	Est_gdp_in_billions IS NOT NULL
# limit 20;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 20 rows affected.
# [('Burundi', 2020, Decimal('70.33'), Decimal('44.33'), Decimal('2.65'), 'Sub-Saharan Africa'),
#  ('Djibouti', 2020, Decimal('69.00'), Decimal('56.00'), Decimal('3.18'), 'Sub-Saharan Africa'),
#  ('Ethiopia', 2020, Decimal('58.00'), Decimal('11.67'), Decimal('107.66'), 'Sub-Saharan Africa'),
#  ('Kenya', 2020, Decimal('67.00'), Decimal('33.67'), Decimal('100.67'), 'Sub-Saharan Africa'),
#  ('Madagascar', 2020, Decimal('56.33'), Decimal('13.00'), Decimal('13.05'), 'Sub-Saharan Africa'),
#  ('Malawi', 2020, Decimal('74.33'), Decimal('28.67'), Decimal('12.18'), 'Sub-Saharan Africa'),
#  ('Mauritius', 2020, Decimal('100.00'), Decimal('96.00'), Decimal('11.40'), 'Sub-Saharan Africa'),
#  ('Mozambique', 2020, Decimal('66.67'), Decimal('40.33'), Decimal('14.03'), 'Sub-Saharan Africa'),
#  ('Rwanda', 2020, Decimal('66.33'), Decimal('64.00'), Decimal('10.18'), 'Sub-Saharan Africa'),
#  ('Somalia', 2020, Decimal('57.33'), Decimal('40.00'), Decimal('6.88'), 'Sub-Saharan Africa'),
#  ('Uganda', 2020, Decimal('61.00'), Decimal('21.67'), Decimal('37.60'), 'Sub-Saharan Africa'),
#  ('Zambia', 2020, Decimal('66.67'), Decimal('32.67'), Decimal('18.11'), 'Sub-Saharan Africa'),
#  ('Zimbabwe', 2020, Decimal('68.00'), Decimal('36.33'), Decimal('21.51'), 'Sub-Saharan Africa'),
#  ('Angola', 2020, Decimal('52.33'), Decimal('47.00'), Decimal('53.62'), 'Sub-Saharan Africa'),
#  ('Cameroon', 2020, Decimal('64.00'), Decimal('43.00'), Decimal('40.77'), 'Sub-Saharan Africa'),
#  ('Central African Republic', 2020, Decimal('38.33'), Decimal('15.00'), Decimal('2.33'), 'Sub-Saharan Africa'),
#  ('Chad', 2020, Decimal('52.67'), Decimal('18.67'), Decimal('10.72'), 'Sub-Saharan Africa'),
#  ('Gabon', 2020, Decimal('73.33'), Decimal('47.00'), Decimal('15.31'), 'Sub-Saharan Africa'),
#  ('Sao Tome and Principe', 2020, Decimal('77.33'), Decimal('46.00'), Decimal('0.47'), 'Sub-Saharan Africa'),
#  ('Botswana', 2020, Decimal('89.67'), Decimal('74.33'), Decimal('14.93'), 'Sub-Saharan Africa')]

# %% [markdown]
# ### Task 4
#
# Lets get an idea if there's any correlation between the GDP and access to basic services for the top 5 economies in Sub-Saharan Africr. The top 5 GDP's are : ('Nigeria','South Africa','Ethiopia','Kenya','Ghana'). Make sure your query only includes these countries.

# %%
# %%sql
# # Add your code here
# SELECT
# 	Country_name,
# 	Time_period,
# 	Pct_managed_drinking_water_services,
# 	Pct_managed_sanitation_services,
# 	Est_gdp_in_billions,
#     region
# FROM
# 	united_nations.Access_to_Basic_Services
# WHERE
# 	region = 'Sub-Saharan Africa'
# AND
#     Country_name NOT IN(
#         'Nigeria',
#         'South Africa',
#         'Ethiopia',
#         'Kenya',
#         'Ghana'
#     )
# AND
# 	Time_period = 2020
# AND
# 	Est_gdp_in_billions IS NOT NULL
#
# ORDER BY Est_gdp_in_billions DESC
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Angola', 2020, Decimal('52.33'), Decimal('47.00'), Decimal('53.62'), 'Sub-Saharan Africa'),
#  ('Cameroon', 2020, Decimal('64.00'), Decimal('43.00'), Decimal('40.77'), 'Sub-Saharan Africa'),
#  ('Uganda', 2020, Decimal('61.00'), Decimal('21.67'), Decimal('37.60'), 'Sub-Saharan Africa'),
#  ('Senegal', 2020, Decimal('85.00'), Decimal('57.00'), Decimal('24.49'), 'Sub-Saharan Africa'),
#  ('Zimbabwe', 2020, Decimal('68.00'), Decimal('36.33'), Decimal('21.51'), 'Sub-Saharan Africa')]

# %% [markdown]
# Based on your results. Is there any correlation between the GDP and access to basic services? Does a higher GDP translate to better services?

# %% [markdown]
# ### Task 5
#
# We only looked at 5 countries in the previous query. Lets have a look at the rest of Sub-Saharan Africa .
# Exclude the countries mentioned in the previous task

# %%
# %%sql
# # Add your code here
#
# SELECT
# 	Country_name,
# 	Time_period,
# 	Pct_managed_drinking_water_services,
# 	Pct_managed_sanitation_services,
# 	Est_gdp_in_billions,
#     region
# FROM
# 	united_nations.Access_to_Basic_Services
# WHERE
# 	region = 'Sub-Saharan Africa'
# AND
#     Country_name IN(
#         'Nigeria',
#         'South Africa',
#         'Ethiopia',
#         'Kenya',
#         'Ghana'
#     )
# AND
# 	Time_period = 2020
# AND
# 	Est_gdp_in_billions IS NOT NULL
#
# ORDER BY Est_gdp_in_billions DESC
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Nigeria', 2020, Decimal('77.33'), Decimal('42.67'), Decimal('432.20'), 'Sub-Saharan Africa'),
#  ('South Africa', 2020, Decimal('92.00'), Decimal('78.67'), Decimal('337.62'), 'Sub-Saharan Africa'),
#  ('Ethiopia', 2020, Decimal('58.00'), Decimal('11.67'), Decimal('107.66'), 'Sub-Saharan Africa'),
#  ('Kenya', 2020, Decimal('67.00'), Decimal('33.67'), Decimal('100.67'), 'Sub-Saharan Africa'),
#  ('Ghana', 2020, Decimal('84.67'), Decimal('23.00'), Decimal('70.04'), 'Sub-Saharan Africa')]

# %% [markdown]
# Again. Do you see any correlation? Arrange the `Pct_managed_drinking_water_services` in descending order. Do the countries with the highest percentage to `Pct_managed_drinking_water_services` have a higher GDP then the countries with a lower percentage of `Pct_managed_drinking_water_services` ?
#  Now arrange the `Pct_managed_sanitation_services` in descending order. Do countries with a higher `Pct_managed_sanitation_services` also have a higher GDP?

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Task 1

# %%
# %%sql
#
# SELECT
# 	Country_name,
# 	Time_period,
# 	Pct_managed_drinking_water_services,
# 	Pct_managed_sanitation_services,
# 	Est_population_in_millions,
# 	Est_gdp_in_billions
# FROM
# 	united_nations.Access_to_Basic_Services
# WHERE
# 	region = ‘Sub-Saharan Africa’
# AND
#     Time_period = 2020;

# %% [markdown]
# ### Task 2

# %%
# %%sql
#
# SELECT
# 	Country_name,
# 	Time_period,
# 	Pct_managed_drinking_water_services,
# 	Pct_managed_sanitation_services,
# 	Est_gdp_in_billions,
#     region
# FROM
# 	united_nations.Access_to_Basic_Services
# WHERE
# 	region = 'Sub-Saharan Africa'
# AND
# 	Time_period = 2020
# AND
# 	Est_gdp_in_billions IS NULL;
#
# # Use LIMIT if you think the results set will be large

# %% [markdown]
# ### Task 3

# %%
# %%sql
#
# SELECT
# 	Country_name,
# 	Time_period,
# 	Pct_managed_drinking_water_services,
# 	Pct_managed_sanitation_services,
# 	Est_gdp_in_billions,
#     	region
# FROM
# 	united_nations.Access_to_Basic_Services
# WHERE
# 	region = 'Sub-Saharan Africa'
# AND
# 	Time_period = 2020
# AND
# 	Est_gdp_in_billions IS NOT NULL;
#
# # Use LIMIT if you think the results set will be large
# # Use ORDER BY Est_gdp_in_billions to order your results

# %% [markdown]
# ### Task 4
#
# Arrange the data in descending order. Comparing Nigeria to South Africa.  We see that Nigeria has a lower percentage in the availability of both water and sanitation services.

# %%
# %%sql
#
# SELECT
# 	Country_name,
# 	Time_period,
# 	Pct_managed_drinking_water_services,
# 	Pct_managed_sanitation_services,
# 	Est_population_in_millions,
# 	Est_gdp_in_billions
# FROM
# 	united_nations.Access_to_Basic_Services
#
# WHERE
# 	Region = ‘Sub-Saharan Africa
# AND
# Time_period = 2020
#
# AND
# 	Est_gdp_in_billions IS NOT NULL
#
# AND
# 	Country_name  NOT IN ('Nigeria','South Africa','Ethiopia','Kenya','Ghana');
#
#
# # Use LIMIT if you think the results set will be large
# # Use ORDER BY Est_gdp_in_billions to order your results

# %% [markdown]
# ### Task 5
#
# Looking at the first entry without ordering any data it is interesting to note that Burundi, with a GDP of only 2.65 Billion has a similar percentage of managed services compared to Nigeria seen in our previous  query(77% and 42%). Nigeria had a percentage of 77 for managed water and 42 for managed sanitation. Arranging the percentage managed drinking water services in descending order.Mauritius with a GDP lower than that of Botswana has better drinking water and sanitation services.

# %%
# %%sql
#
# SELECT
# 	Country_name,
# 	Time_period,
# 	Pct_managed_drinking_water_services,
# 	Pct_managed_sanitation_services,
# 	Est_population_in_millions,
# 	Est_gdp_in_billions
# FROM
# 	united_nations.Access_to_Basic_Services
#
# WHERE
# 	Region = ‘Sub-Saharan Africa
# AND
# Time_period = 2020
#
# AND
# 	Est_gdp_in_billions IS NOT NULL
#
# AND
# 	Country_name  IS IN ('Nigeria','South Africa','Ethiopia','Kenya','Ghana');
#
# # Use LIMIT if you think the results set will be large
# # Use ORDER BY Est_gdp_in_billions to order your results by GDP
# # Use ORDER BY Pct_managed_drinking_water_services to order percentage managed drinking water services
# # Use ORDER BY Pct_managed_sanitation_services to order your results by percentage managed sanitation services

# %% [markdown]
# ## Summary
#
# In this exercise we used the IS NULL statement to determine if there were any null values in the GDP column.
# We then used the IS NOT NULL statement to exclude those nulls.
# We looked at the top 5 GDP's in Sub-Saharan Africa by using the IS IN statement.
# We had a look at the rest of the Sub-Saharan African countries by excluding the top 5 GDP's using the IS NOT IN statement
# Based on the quick perusal of the data in Sub-Saharan africa, we can conclude that there isn’t
# any noticeable correlation between GDP and the availability of drinking water and sanitation services.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
